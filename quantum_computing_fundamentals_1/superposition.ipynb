# %%
# !pip3 install qiskit
# !pip3 install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: qiskit in /Users/student/Library/Python/3.12/lib/python/site-packages (2.3.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /Users/student/Library/Python/3.12/lib/python/site-packages (from qiskit) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.17 in /Users/student/Library/Python/3.12/lib/python/site-packages (from qiskit) (2.4.1)
# Requirement already satisfied: scipy>=1.5 in /Users/student/Library/Python/3.12/lib/python/site-packages (from qiskit) (1.17.0)
# Requirement already satisfied: dill>=0.3 in /Users/student/Library/Python/3.12/lib/python/site-packages (from qiskit) (0.4.1)
# Requirement already satisfied: stevedore>=3.0.0 in /Users/student/Library/Python/3.12/lib/python/site-packages (from qiskit) (5.6.0)
# Requirement already satisfied: typing-extensions in /Users/student/Library/Python/3.12/lib/python/site-packages (from qiskit) (4.15.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: pip3 install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /Users/student/Library/Python/3.12/lib/python/site-packages (2.4.1)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: pip3 install --upgrade pip

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from numpy import pi

qreg_q = QuantumRegister(4, 'q')
creg_c = ClassicalRegister(4, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.h(qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.measure(qreg_q[0], creg_c[2])
circuit.measure(qreg_q[1], creg_c[3])

circuit.draw("text")
# Out:
#      ┌───┐     ┌─┐
# q_0: ┤ H ├──■──┤M├───
#      └───┘┌─┴─┐└╥┘┌─┐
# q_1: ─────┤ X ├─╫─┤M├
#           └───┘ ║ └╥┘
# q_2: ───────────╫──╫─
#                 ║  ║
# q_3: ───────────╫──╫─
#                 ║  ║
# c: 4/═══════════╩══╩═
#                 2  3

# %%
# !pip3 install numpy 
# !pip3 install qiskit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in /Users/student/Library/Python/3.12/lib/python/site-packages (2.4.1)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: pip3 install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: qiskit in /Users/student/Library/Python/3.12/lib/python/site-packages (2.3.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /Users/student/Library/Python/3.12/lib/python/site-packages (from qiskit) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.17 in /Users/student/Library/Python/3.12/lib/python/site-packages (from qiskit) (2.4.1)
# Requirement already satisfied: scipy>=1.5 in /Users/student/Library/Python/3.12/lib/python/site-packages (from qiskit) (1.17.0)
# Requirement already satisfied: dill>=0.3 in /Users/student/Library/Python/3.12/lib/python/site-packages (from qiskit) (0.4.1)
# Requirement already satisfied: stevedore>=3.0.0 in /Users/student/Library/Python/3.12/lib/python/site-packages (from qiskit) (5.6.0)
# Requirement already satisfied: typing-extensions in /Users/student/Library/Python/3.12/lib/python/site-packages (from qiskit) (4.15.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: pip3 install --upgrade pip

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from numpy import pi

qreg_q = QuantumRegister(4, 'q')
creg_c = ClassicalRegister(4, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.h(qreg_q[1])
circuit.measure(qreg_q[1], creg_c[1])

# %% [markdown]
# # Learning Notes: Deutsch-Jozsa Algorithm
#
# ## Day 5 notes
#
# ---
#
# ## Checkbox
# - test 1
#
# [] checkbox
