# %%
# !pip3 install qiskit
# !pip3 install numpy

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from numpy import pi

qreg_q = QuantumRegister(4, 'q')
creg_c = ClassicalRegister(4, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.h(qreg_q[0])
circuit.cx(qreg_q[0], qreg_q[1])
circuit.measure(qreg_q[0], creg_c[2])
circuit.measure(qreg_q[1], creg_c[3])

circuit.draw("text")
# Out:
#      ┌───┐     ┌─┐
# q_0: ┤ H ├──■──┤M├───
#      └───┘┌─┴─┐└╥┘┌─┐
# q_1: ─────┤ X ├─╫─┤M├
#           └───┘ ║ └╥┘
# q_2: ───────────╫──╫─
#                 ║  ║
# q_3: ───────────╫──╫─
#                 ║  ║
# c: 4/═══════════╩══╩═
#                 2  3

# %%
# !pip3 install numpy 
# !pip3 install qiskit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting numpy
#   Obtaining dependency information for numpy from https://files.pythonhosted.org/packages/8e/43/9762e88909ff2326f5e7536fa8cb3c49fb03a7d92705f23e6e7f553d9cb3/numpy-2.4.1-cp312-cp312-macosx_14_0_arm64.whl.metadata
#   Downloading numpy-2.4.1-cp312-cp312-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Downloading numpy-2.4.1-cp312-cp312-macosx_14_0_arm64.whl (5.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 22.7 MB/s eta 0:00:0000:0100:01
# Installing collected packages: numpy
# Successfully installed numpy-2.4.1
#
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: pip3 install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Collecting qiskit
#   Obtaining dependency information for qiskit from https://files.pythonhosted.org/packages/d7/55/bb8efb2b6e46e5b8c7d147973646fa71677e63ecd2378af4db2829795be6/qiskit-2.3.0-cp310-abi3-macosx_11_0_arm64.whl.metadata
#   Downloading qiskit-2.3.0-cp310-abi3-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting rustworkx>=0.15.0 (from qiskit)
#   Obtaining dependency information for rustworkx>=0.15.0 from https://files.pythonhosted.org/packages/23/ae/7b6bbae5e0487ee42072dc6a46edf5db9731a0701ed648db22121fb7490c/rustworkx-0.17.1-cp39-abi3-macosx_11_0_arm64.whl.metadata
#   Downloading rustworkx-0.17.1-cp39-abi3-macosx_11_0_arm64.whl.metadata (10 kB)
# Requirement already satisfied: numpy<3,>=1.17 in /Users/student/Library/Python/3.12/lib/python/site-packages (from qiskit) (2.4.1)
# Collecting scipy>=1.5 (from qiskit)
#   Obtaining dependency information for scipy>=1.5 from https://files.pythonhosted.org/packages/e3/21/f6ec556c1e3b6ec4e088da667d9987bb77cc3ab3026511f427dc8451187d/scipy-1.17.0-cp312-cp312-macosx_14_0_arm64.whl.metadata
#   Downloading scipy-1.17.0-cp312-cp312-macosx_14_0_arm64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 2.0 MB/s eta 0:00:00
# Collecting dill>=0.3 (from qiskit)
#   Obtaining dependency information for dill>=0.3 from https://files.pythonhosted.org/packages/1e/77/dc8c558f7593132cf8fefec57c4f60c83b16941c574ac5f619abb3ae7933/dill-0.4.1-py3-none-any.whl.metadata
#   Downloading dill-0.4.1-py3-none-any.whl.metadata (10 kB)
# Collecting stevedore>=3.0.0 (from qiskit)
#   Obtaining dependency information for stevedore>=3.0.0 from https://files.pythonhosted.org/packages/f4/40/8561ce06dc46fd17242c7724ab25b257a2ac1b35f4ebf551b40ce6105cfa/stevedore-5.6.0-py3-none-any.whl.metadata
#   Downloading stevedore-5.6.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting typing-extensions (from qiskit)
#   Obtaining dependency information for typing-extensions from https://files.pythonhosted.org/packages/18/67/36e9267722cc04a6b9f15c7f3441c2363321a3ea07da7ae0c0707beb2a9c/typing_extensions-4.15.0-py3-none-any.whl.metadata
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Downloading qiskit-2.3.0-cp310-abi3-macosx_11_0_arm64.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 29.0 MB/s eta 0:00:0000:0100:01
# Downloading dill-0.4.1-py3-none-any.whl (120 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.0/120.0 kB 15.1 MB/s eta 0:00:00
# Downloading rustworkx-0.17.1-cp39-abi3-macosx_11_0_arm64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 18.9 MB/s eta 0:00:00a 0:00:01
# Downloading scipy-1.17.0-cp312-cp312-macosx_14_0_arm64.whl (20.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 28.4 MB/s eta 0:00:0000:0100:01
# Downloading stevedore-5.6.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 6.7 MB/s eta 0:00:00
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 5.8 MB/s eta 0:00:00
# Installing collected packages: typing-extensions, stevedore, scipy, rustworkx, dill, qiskit
# Successfully installed dill-0.4.1 qiskit-2.3.0 rustworkx-0.17.1 scipy-1.17.0 stevedore-5.6.0 typing-extensions-4.15.0
#
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: pip3 install --upgrade pip

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from numpy import pi

qreg_q = QuantumRegister(4, 'q')
creg_c = ClassicalRegister(4, 'c')
circuit = QuantumCircuit(qreg_q, creg_c)

circuit.h(qreg_q[1])
circuit.measure(qreg_q[1], creg_c[1])
